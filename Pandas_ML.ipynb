# %% [markdown]
# **Pandas is the python library used for working with datasets.
# It has functions for analyzing,cleaning,exploring and manupulation data**

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8960\4080736814.py in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print('hello')

# %%
iris_df = pd.read_csv('Iris_Data.csv')
print(iris_df)
print(type(iris_df))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame = iris_df.copy()
print(data_frame)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(data_frame.shape)
print(data_frame.dtypes)
# Out:
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data_frame.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
data_frame['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
data_frame.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data_frame.iloc[0:3,0:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
data_frame.iloc[0:1,0:2]
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5

# %%
new_df = data_frame.copy()
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
new_df.drop(2,inplace = True)  # works with labels
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
new_df.index
# Out:
# RangeIndex(start=5, stop=150, step=1)

# %%
new_df.index[0]
# Out:
# 5

# %%
new_df.drop(new_df.index[0],inplace=True)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df=iris_df.copy()
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.petal_length > 0.2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: petal_length, Length: 150, dtype: bool

# %%
df[df.petal_length > 0.2].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df[df.species=='virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.iloc[0])   # works with position orindex
print(df.loc[0])    # works with labels
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.loc[150]= [0.3,3.4,1.5,0.2,'waghraj']
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 150           0.3          3.4           1.5          0.2    waghraj

# %%
new_df.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    145.000000     145.00000   145.000000
# mean       5.877241       3.84000     1.233103
# std        0.820717       1.73819     0.752870
# min        4.300000       1.00000     0.100000
# 25%        5.200000       1.60000     0.400000
# 50%        5.800000       4.40000     1.300000
# 75%        6.400000       5.10000     1.800000
# max        7.900000       6.90000     2.500000

# %%
new_df['color']='white'

# %%
print(new_df)
# Out:
#      sepal_length  petal_length  petal_width    species  color
# 5             5.4           1.7          0.4     setosa  white
# 6             4.6           1.4          0.3     setosa  white
# 7             5.0           1.5          0.2     setosa  white
# 8             4.4           1.4          0.2     setosa  white
# 9             4.9           1.5          0.1     setosa  white
# ..            ...           ...          ...        ...    ...
# 145           6.7           5.2          2.3  virginica  white
# 146           6.3           5.0          1.9  virginica  white
# 147           6.5           5.2          2.0  virginica  white
# 148           6.2           5.4          2.3  virginica  white
# 149           5.9           5.1          1.8  virginica  white
#
# [145 rows x 5 columns]

# %%
import numpy as np

# %%
df.iloc[2:3,3:4] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          NaN  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
df.iloc[2:5,2:4] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           NaN          NaN  setosa
# 3           5.0          3.6           NaN          NaN  setosa
# 4           5.4          3.9           NaN          NaN  setosa

# %%
df.petal_length.fillna(df.petal_length.mean(),inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000          0.2  setosa
# 1           4.9          3.0      1.400000          0.2  setosa
# 2           4.6          3.1      3.805442          NaN  setosa
# 3           5.0          3.6      3.805442          NaN  setosa
# 4           5.4          3.9      3.805442          NaN  setosa

# %%
df.petal_width.fillna(df.petal_width.mean(),inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.6          3.1      3.805442     1.217687  setosa
# 3           5.0          3.6      3.805442     1.217687  setosa
# 4           5.4          3.9      3.805442     1.217687  setosa

# %%
df.iloc[2:3,3:4] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.6          3.1      3.805442          NaN  setosa
# 3           5.0          3.6      3.805442     1.217687  setosa
# 4           5.4          3.9      3.805442     1.217687  setosa

# %%
temp = df[df.species == 'setosa']

df.petal_width.fillna(temp.petal_width.mean(),inplace=True)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.6          3.1      3.805442     0.284070  setosa
# 3           5.0          3.6      3.805442     1.217687  setosa
# 4           5.4          3.9      3.805442     1.217687  setosa
